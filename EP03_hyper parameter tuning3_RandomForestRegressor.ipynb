# %%
import warnings
warnings.filterwarnings("ignore")

import os
from os.path import join

import pandas as pd
import numpy as np

import missingno as msno

from sklearn.model_selection import KFold, cross_val_score

# %%
train_data_path = join('./data', 'train.csv')
test_data_path = join('./data', 'test.csv')

train = pd.read_csv(train_data_path)
test = pd.read_csv(test_data_path)

# %%
train['date'] = train['date'].apply(lambda i: i[:6]).astype(int)
del train['id']
train.head()
# Out:
#      date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  201410  221900.0         3       1.00         1180      5650     1.0
# 1  201502  180000.0         2       1.00          770     10000     1.0
# 2  201502  510000.0         3       2.00         1680      8080     1.0
# 3  201406  257500.0         3       2.25         1715      6819     2.0
# 4  201501  291850.0         3       1.50         1060      9711     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      6         770              0      1933
# 2           0     0          3      8        1680              0      1987
# 3           0     0          3      7        1715              0      1995
# 4           0     0          3      7        1060              0      1963
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1             0    98028  47.7379 -122.233           2720        8062
# 2             0    98074  47.6168 -122.045           1800        7503
# 3             0    98003  47.3097 -122.327           2238        6819
# 4             0    98198  47.4095 -122.315           1650        9711

# %%
y = train['price']
del train['price']

y.head(), y.shape
# Out:
# (0    221900.0
#  1    180000.0
#  2    510000.0
#  3    257500.0
#  4    291850.0
#  Name: price, dtype: float64,
#  (15035,))

# %%
test['date'] = test['date'].apply(lambda i: i[:6]).astype(int)
del test['id']
test.head(3)
# Out:
#      date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  201412         3       2.25         2570      7242     2.0           0
# 1  201412         4       3.00         1960      5000     1.0           0
# 2  201405         4       4.50         5420    101930     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        2170            400      1951          1991
# 1     0          5      7        1050            910      1965             0
# 2     0          3     11        3890           1530      2001             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# 0    98125  47.7210 -122.319           1690        7639
# 1    98136  47.5208 -122.393           1360        5000
# 2    98053  47.6561 -122.005           4760      101930

# %% [markdown]
# ---

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor

# %%
random_state=2020
rdforest = RandomForestRegressor(random_state=random_state)
model = rdforest

# %%
def rmse(y_test, y_pred):
    return np.sqrt(mean_squared_error(np.expm1(y_test), np.expm1(y_pred)))

# %%
param_grid = {'n_estimators': [50, 100], 'max_depth' : [1, 10],}

# %%
from sklearn.model_selection import GridSearchCV
grid_model = GridSearchCV(model, param_grid=param_grid,
                         scoring='neg_mean_squared_error',
                         cv=5, verbose=2, n_jobs=5)

# %%
def my_GridSearch_rdforest(model, train, y, param_grid, verbose=2, n_jobs=5):
    grid_model = GridSearchCV(model, param_grid=param_grid, scoring='neg_mean_squared_error', cv=5, verbose=verbose, n_jobs=n_jobs)
    
    grid_model.fit(train, y)

    params = grid_model.cv_results_['params']
    score = grid_model.cv_results_['mean_test_score']

    hyper = pd.DataFrame(params)
    hyper['score'] = score

    hyper['RMSLE'] = np.sqrt(-1 * hyper['score'])
    hyper = hyper.sort_values('RMSLE')


    return hyper

# %%
my_GridSearch_rdforest(model, train, y , param_grid, verbose=2, n_jobs=5)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
#    max_depth  n_estimators         score          RMSLE
# 2         10            50 -1.964140e+10  140147.778612
# 3         10           100 -1.970500e+10  140374.511226
# 1          1           100 -8.478973e+10  291186.754734
# 0          1            50 -8.480056e+10  291205.363331

# %% [markdown]
# ## 하이퍼 파라미터 튜닝 및 RMSLE 변화 관찰

# %% [markdown]
# __(test1) max_depth 깊을수록, n_estimators가 적을수록 RMSLE 값이 작음. max_depth값에 제한을 두지 않고 무한대로 늘려보자(-1)__

# %%
param_grid ={'n_estimators': [50, 100], 'max_depth': [3, 5, 10, 50],}
model = rdforest
my_GridSearch_rdforest(model, train, y , param_grid, verbose=2, n_jobs=5)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
#    max_depth  n_estimators         score          RMSLE
# 7         50           100 -1.824707e+10  135081.711998
# 6         50            50 -1.846271e+10  135877.542137
# 4         10            50 -1.964140e+10  140147.778612
# 5         10           100 -1.970500e+10  140374.511226
# 2          5            50 -3.136200e+10  177093.200631
# 3          5           100 -3.158370e+10  177718.041942
# 0          3            50 -4.812460e+10  219373.207904
# 1          3           100 -4.843739e+10  220084.954760

# %%
param_grid ={'n_estimators': [50, 100], 'max_depth': [500],}
model = rdforest
my_GridSearch_rdforest(model, train, y , param_grid, verbose=2, n_jobs=5)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
#    max_depth  n_estimators         score          RMSLE
# 1        500           100 -1.824707e+10  135081.711998
# 0        500            50 -1.846271e+10  135877.542137

# %%
param_grid ={'bootstrap': [True, False], 'max_depth': [50],
             'max_features': ['auto', 'sqrt'],
             'min_samples_leaf': [1, 2, 4], 
             'min_samples_split': [2, 5, 10],
             'n_estimators': [10}
model = rdforest
my_GridSearch_rdforest(model, train, y , param_grid, verbose=2, n_jobs=5)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#     bootstrap  max_depth max_features  min_samples_leaf  min_samples_split  \
# 3        True         50         auto                 2                  2
# 4        True         50         auto                 2                  5
# 29      False         50         sqrt                 1                 10
# 31      False         50         sqrt                 2                  5
# 32      False         50         sqrt                 2                 10
# 0        True         50         auto                 1                  2
# 5        True         50         auto                 2                 10
# 27      False         50         sqrt                 1                  2
# 2        True         50         auto                 1                 10
# 1        True         50         auto                 1                  5
# 33      False         50         sqrt                 4                  2
# 34      False         50         sqrt                 4                  5
# 8        True         50         auto                 4                 10
# 6        True         50         auto                 4                  2
# 7        True         50         auto                 4                  5
# 28      False         50         sqrt                 1                  5
# 35      False         50         sqrt                 4                 10
# 30      False         50         sqrt                 2                  2
# 13       True         50         sqrt                 2                  5
# 14       True         50         sqrt                 2                 10
# 12       True         50         sqrt                 2                  2
# 10       True         50         sqrt                 1                  5
# 11       True         50         sqrt                 1                 10
# 17       True         50         sqrt                 4                 10
# 9        True         50         sqrt                 1                  2
# 16       True         50         sqrt                 4                  5
# 15       True         50         sqrt                 4                  2
# 26      False         50         auto                 4                 10
# 24      False         50         auto                 4                  2
# 25      False         50         auto                 4                  5
# 23      False         50         auto                 2                 10
# 20      False         50         auto                 1                 10
# 22      False         50         auto                 2                  5
# 19      False         50         auto                 1                  5
# 18      False         50         auto                 1                  2
# 21      False         50         auto                 2                  2
#
#     n_estimators         score          RMSLE
# 3             10 -2.030582e+10  142498.495960
# 4             10 -2.072620e+10  143965.951116
# 29            10 -2.080079e+10  144224.803575
# 31            10 -2.096019e+10  144776.354722
# 32            10 -2.102791e+10  145010.033230
# 0             10 -2.108631e+10  145211.275325
# 5             10 -2.135546e+10  146135.074169
# 27            10 -2.154364e+10  146777.531431
# 2             10 -2.160191e+10  146975.883093
# 1             10 -2.160211e+10  146976.569185
# 33            10 -2.178726e+10  147605.094433
# 34            10 -2.178726e+10  147605.094433
# 8             10 -2.194837e+10  148149.826150
# 6             10 -2.200564e+10  148342.964478
# 7             10 -2.200564e+10  148342.964478
# 28            10 -2.221228e+10  149037.861968
# 35            10 -2.224840e+10  149158.989539
# 30            10 -2.264053e+10  150467.698053
# 13            10 -2.267120e+10  150569.597873
# 14            10 -2.360449e+10  153637.541178
# 12            10 -2.365225e+10  153792.880613
# 10            10 -2.404975e+10  155079.813552
# 11            10 -2.423060e+10  155661.801180
# 17            10 -2.426309e+10  155766.128487
# 9             10 -2.438919e+10  156170.393147
# 16            10 -2.660313e+10  163104.666416
# 15            10 -2.660313e+10  163104.666416
# 26            10 -3.139119e+10  177175.591167
# 24            10 -3.145326e+10  177350.671768
# 25            10 -3.145326e+10  177350.671768
# 23            10 -3.216681e+10  179351.076088
# 20            10 -3.219022e+10  179416.327678
# 22            10 -3.282472e+10  181175.941590
# 19            10 -3.331075e+10  182512.321730
# 18            10 -3.331692e+10  182529.221722
# 21            10 -3.377889e+10  183790.348346

# %% [markdown]
# randomforest regressor 모델도 max_depth와 n_estimator만 조합했을 때, RMSLE가 가장 낮다. 그런데 왜이렇게 수치가 높은지는 의문이다.

# %% [markdown]
# __RMSLE = 142498.495960__
